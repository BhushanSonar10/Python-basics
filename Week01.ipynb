# %% [markdown]
# <a href="https://colab.research.google.com/github/BhushanSonar10/Python-basics/blob/main/Week01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=int(input('enter the age'))
# Out:
# enter the age45

# %%
age=int(input('enter the age'))
print(age>18 and age<60)
print(age>18 and age<21)
# Out:
# enter the age78
# False
# False

# %%
print(0XF & 0XE)
# Out:
# 14

# %%
print(8^12)
print(8|12)
# Out:
# 4
# 12

# %%
a=8
print(a)
a+=3
print(a)
a-=6
print(a)
# Out:
# 8
# 11
# 5

# %%
print(8&12)
# Out:
# 8

# %%
x=10
print(x)
x/=5
print(x)
x%=2
print(x)
x//=3
print(x)
x**=10
print(x)
# Out:
# 10
# 2.0
# 0.0
# 0.0
# 0.0

# %%
x=('hubli','jamkhandi')
y=('hubli','jamkhandi')
z=x
z=y
print(z is x)
print(y is x)
print(z is y)
# Out:
# False
# False
# True

# %%
num=int(input('Enter the number'))
while num<=9:
 print('number is single digit')
 break
while num>9 and num<=99:
  print('numnber is double digit')
  break
else:
   print('number has more than two digits')
# Out:
# Enter the number5
# number is single digit
# number has more than two digits

# %%
for x in range(6):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(1,20,3):
 print(x)
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19

# %%
for x in range(5,9):
 print("single digit number")
# Out:
# single digit number
# single digit number
# single digit number
# single digit number

# %% [markdown]
# Functions
# 1.Define the function
# 2.invoking the function
# 3.passing the arguments

# %%
def cake_baker(p,f,s):
  print("no.of pieces=",p)
  print("flavour is=",f)
  print("size is=",s)
cake_baker("5","chocolate","2kg")
cake_baker("100","vanilla","3kg")
# Out:
# no.of pieces= 5
# flavour is= chocolate
# size is= 2kg
# no.of pieces= 100
# flavour is= vanilla
# size is= 3kg

# %%
def add(*bunch):
  sum=0
  for i in bunch:
    sum+=i
  return sum
print(add(1,2,3,4,5))
# Out:
# 15

# %%
def greet(**kwargs):
  print("Hello")
  for key, value in kwargs.items():
    print(value, end=" ")

greet(name="Bhushan",sem="5")
# Out:
# Hello
# Bhushan 5

# %%
print(8>>1)
# Out:
# 4

# %%
print(8>>2)
# Out:
# 2

# %%
print(8<<2)
# Out:
# 32

# %%
import random
x= random.randint(1,9)
print(x)
# Out:
# 1

# %%
import random
x= random.randint(1,9)
print(x)

a=random.random()
print(a)
# Out:
# 2
# 0.4903035259773564

# %% [markdown]
# lottery game

# %%
import random
computer=random.randint(1,9)
userinput=int(input("Enter the number between 1 and 9"))
print(computer)
print(userinput)
if computer>userinput:
   print("Computer won")
elif computer==userinput:
   print("TIE")
else:
   print("You won")
# Out:
# Enter the number between 1 and 98
# 2
# 8
# You won

# %%
import random
gamelist=['rock','paper','scissor']
c=random.choice(gamelist)
user=input("Enter either rock or paper or scissor")
print(c)
print(user)
if(c=='rock'and user=='paper'):
  print('computer won')
elif (c=="paper" and user=="scissor"):
  print("You won")
elif(c=="scissor"and user=="paper"):
  print("computer won")
else:
  print('TIE')
# Out:
# Enter either rock or paper or scissorrock
# scissor
# rock
# TIE

# %% [markdown]
# NumPy-Numerical Python

# %%
import numpy as np
a=np.array([1,45,23,89])
print(type(a))
b=np.zeros(2)
c=np.ones(4)
print(b)
print(c)
d=np.sort(a)
print(d)
# Out:
# <class 'numpy.ndarray'>
# [0. 0.]
# [1. 1. 1. 1.]
# [ 1 23 45 89]

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.1

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,1,10)
m=0.6
c=25
y= m*x + c
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,1,9)
y= np.sin(x)
fig, a=plt.subplot()
a=plot(x,y,linewidth=3.0)

a.set(xlim=(0,9),xticks=np.arrange(1,9),
      ylim=(0,9),yticks=np.arrange(1,9))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-88ea2a80687f> in <cell line: 5>()
#       3 x=np.linspace(0,1,9)
#       4 y=np.sin(x)
# ----> 5 fig, a=plt.subplot()
#       6 a=plt(x,y,linewidth=3.0)
#       7 a.set(xlim=(0,9),xticks=np.arrange(1,9),
#
# TypeError: cannot unpack non-iterable Axes object

# %%
import matplotlib.pyplot as plt
import numpy as np
temp=np.array([10,20,30,40,50,60,70,80])
res=np.array([18476,12185,10000,8260,5740,4080,2960,2188])
plt.scatter(temp,res)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
temp=np.array([10,20,30,40,50,60,70,80])
res=np.array([18476,12185,10000,8260,5740,4080,2960,2188])
plt.plot(temp,res)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
temp=np.array([10,20,30,40,50,60,70,80])
res=np.array([18476,12185,10000,8260,5740,4080,2960,2188])
plt.plot(res,marker='*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
temp=np.array([10,20,30,40,50,60,70,80])
res=np.array([18476,12185,10000,8260,5740,4080,2960,2188])
plt.plot(res,marker='*')
plt.title('thermister characteristics')
plt.xlabel('temp')
plt.ylabel('res')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['ka','Tn','Ap','Tg'])
y=np.array([100,231,150,123])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(5,1,10000)
plt.hist(x,100)
plt.show()

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Python/data.csv')
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/drive/MyDrive/Python/data.csv')

df.plot()
# Out:
# <Axes: >

# %%
x=input('enter string')
print(x)
for i in  range (9):
 sum-=i
rev('string')
y=input(rev('string'))
if x==y:
 print('entered string is palindrome')
else:
 print('entered string is not palindrome')
# Out:
# enter stringhello
# hello
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-6a169ee7b435> in <cell line: 3>()
#       2 print(x)
#       3 for i in  range (9):
# ----> 4  sum-=i
#       5 rev('string')
#       6 y=input(rev('string'))
#
# TypeError: unsupported operand type(s) for -=: 'builtin_function_or_method' and 'int'

# %%
x=int(input('n'))
print(x)
if x%2==0:
 print('even')
else:
  print('odd')
# Out:
# n5
# 5
# odd

# %%
rows=int(input('enter no of rows'))
mystring=''
for i in range(1, rows + 1):
  mystring+='*'
  print(mystring)
# Out:
# enter no of rows7
# *
# **
# ***
# ****
# *****
# ******
# *******

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,5,13,25,33,46]).reshape([-1,1])
y=np.array([3,6,9,12,14,18])
plt.scatter(x,y)
plt.ylabel("DV")
plt.xlabel("IV")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='Red',marker='*')
print("MSE:",mse)
print("intercept:",SLR.intercept_)
print("slope:",SLR.coef_)
# Out:
# MSE: 0.5056719506337065
# intercept: 3.938587739718434
# slope: [0.31193881]
